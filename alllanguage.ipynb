// %% [markdown]
// Loop in Python

// %%
for i in range(5):
    print(i)

// %%
#include <iostream>
using namespace std;

int age = 20;

if(age >= 18){
    cout << "Adult";
}
else{
    cout << "Minor";
}

// %%
#include<iostream> 
using namespace std;

for(int i = 1; i <= 4; i++){
    for(int j = 1; j <= 3; j++){
        cout << " * ";
    }
    cout << endl;
}
// Out:
// |   #include<iostream>
// illegal character: '#'
//
// |   using namespace std;
// '(' expected

// %%
for(int i = 1; i <= 5; i++){
    for(int j = 1; j <= 5; j++){
        cout << " * ";
    }

    cout << endl;
}
